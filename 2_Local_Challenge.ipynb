# %% [markdown]
# # 2. Identify a local challenge

# %% [markdown]
# Country: Switzerland
#
# Region: Swiss Alps Jungfrau–Aletsch area, focusing on the Great Aletsch Glacier and neighbouring glacierised catchments.
#
# Challenge:
# - With climate change and global warming, glaciers are shrinking.
#
#
#
# Tourism and potential projects such as hydropower within and around the site, and cable cars pose a certain threat

# %% [markdown]
# This research will focus on the glaciers of Switzerland
